# %%
import os
os.chdir('../../')

import pandas as pd
import numpy as np
import random
from sklearn.model_selection import train_test_split

from preprocessing.triplets import generate_triplet_dataset

# %%
DATA_FOLDER = './data/'
TRAIN_CSV = 'train.csv'
TRIPLETS_CSV = 'triplets_train.csv'
SEED = 11

# %%
train_df = pd.read_csv(DATA_FOLDER + TRAIN_CSV)

# %% [markdown]
# ### Split train.csv dataset with stratification. Seed fixed.

# %%
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)

# %%
X_train = np.arange(len(train_df))
y_train = train_df['is_duplicate'].to_numpy()
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, stratify=y_train)
train_df = train_df.iloc[X_train]

# %% [markdown]
# ### Generate and save triplets

# %%
triplet_train_df = pd.DataFrame(generate_triplet_dataset(train_df))
triplet_train_df.to_csv(DATA_FOLDER + TRIPLETS_CSV)

# %%
triplet_train_df
# Out:
#         bucket  anchor_id                                           anchor_q  \
# 0            4      21120       How can green tea help you reduce belly fat?
# 1            4      21120       How can green tea help you reduce belly fat?
# 2            4      21120       How can green tea help you reduce belly fat?
# 3            4      21120       How can green tea help you reduce belly fat?
# 4            4      21120       How can green tea help you reduce belly fat?
# ...        ...        ...                                                ...
# 660037  411312     369310  Who has killed the most people first hand in h...
# 660038  411312     369310  Who has killed the most people first hand in h...
# 660039  411313     362182  Do hummingbirds hibernate? If not, how do they...
# 660040  411313     362182  Do hummingbirds hibernate? If not, how do they...
# 660041  411313     362182  Do hummingbirds hibernate? If not, how do they...
#
#         pos_id                                              pos_q  neg_id  \
# 0       231446  How healthy is Lipton's bottled citrus green t...  261841
# 1       231446  How healthy is Lipton's bottled citrus green t...  513883
# 2       231446  How healthy is Lipton's bottled citrus green t...  297167
# 3        24353  Does drinking green tea for weight loss really...  513883
# 4        24353  Does drinking green tea for weight loss really...  513883
# ...        ...                                                ...     ...
# 660037  369311  Who has killed the most people with his hands ...  386164
# 660038  369311  Who has killed the most people with his hands ...  429399
# 660039  362183  How do hummingbirds avoid freezing in cold wea...  290291
# 660040  362183  How do hummingbirds avoid freezing in cold wea...  223276
# 660041  362183  How do hummingbirds avoid freezing in cold wea...  516592
#
#                                                     neg_q
# 0       Which one is better for weight reducing, black...
# 1       How many people in Quora have actually lost we...
# 2       Can 2 cups of drinking green tea after a binge...
# 3       How many people in Quora have actually lost we...
# 4       How many people in Quora have actually lost we...
# ...                                                   ...
# 660037    What do Australians think of American gun laws?
# 660038                           How do I be less lonely?
# 660039  What is the meaning and origin of the Punjabi ...
# 660040                           What is 64bit computing?
# 660041  What does the expression "narrow the field" mean?
#
# [660042 rows x 7 columns]
